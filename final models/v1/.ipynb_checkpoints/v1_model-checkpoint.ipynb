# %%
import chess
import chess_game_tracker

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

tokens_filepath = "tokens.txt"
model_filepath = "v1_model"

# hyperparameters
block_size = 64 # what is the maximum context length for predictions?
eval_iters = 100
n_embd = 400
n_head = 4
n_layer = 4
dropout = 0.0


device = 'cpu'

# %%
with open(tokens_filepath, "r") as f:
    tokens = f.read().splitlines()
    
tokens = ["ZERO", "START"] + tokens

token_to_int = {}
int_to_token = {}

for i, token in enumerate(tokens):
    token_to_int[token] = i
    int_to_token[i] = token
    
def encode(lst):
    return [token_to_int[token] for token in lst]
def decode(lst):
    return [int_to_token[i] for i in lst]

vocab_size = len(tokens)
print (vocab_size)
# Out:
# 360

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

# %%
def generate(model, idx, max_new_tokens, game):
    # idx is (B, T) array of indices in the current context
    for _ in range(max_new_tokens):
        # crop idx to the last block_size tokens
        idx_cond = idx[:, -block_size:]
        # get the predictions
        logits, loss = model(idx_cond)
        # focus only on the last time step
        logits = logits[:, -1, :] # becomes (B, C)

        legal_moves = encode(game.encoded_legal_moves())
#         print (legal_moves)
        if len(legal_moves) == 0:
            return idx

        for i in range(vocab_size):
            if i not in legal_moves:
                logits[0, i] = -100000
        
        # apply softmax to get probabilities
        probs = F.softmax(logits, dim=-1) # (B, C)
        # sample from the distribution
        idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
        
#         print (idx_next,  idx_next.tolist()[0], "hi")
        assert idx_next.tolist()[0][0] in legal_moves
        
        game.make_move(decode(idx_next.tolist()[0])[0])
        
        # append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
    return idx

# %%
model = BigramLanguageModel()
# print the number of parameters in the model
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# 8.01076 M parameters

# %%
model.load_state_dict(torch.load(model_filepath + "_state.pt"))
# Out:
# <All keys matched successfully>

# %%
game = chess_game_tracker.Game()
context = torch.zeros((1, 1), dtype=torch.long, device=device)
context[0][0] = 1
print(decode(generate(model, idx = context, max_new_tokens=100, game=game)[0].tolist()))
print (game.get_game_pgn())
# Out:
# ['START', 'Pawn:e2:TwoPush', 'Pawn:g7:Push', 'Pawn:d2:TwoPush', 'N1:-1:-2', 'Pawn:c2:Push', 'Pawn:e7:Push', 'BD:g5', 'BD:e7', 'BD:f6', 'BD:f6', 'BL:c4', 'Pawn:c7:Push', 'N2:-2:1', 'Pawn:d7:TwoPush', 'Pawn:e4:CaptureLeft', 'Pawn:c6:CaptureRight', 'BL:b3', 'BL:d7', 'K:2:0', 'N2:-2:-1', 'N2:2:1', 'BD:g5', 'Pawn:h2:Push', 'BL:c6', 'Pawn:a2:Push', 'Pawn:b7:TwoPush', 'N1:2:1', 'K:2:0', 'Q:f3', 'N1:1:-2', 'Q:g4', 'BD:h6', 'N1:1:2', 'Pawn:f7:TwoPush', 'Q:d1', 'Pawn:f5:CaptureLeft', 'N2:-1:2', 'Q:e8', 'N2:1:-2', 'R1:2:0', 'N2:-1:2', 'Q:d7', 'Pawn:g2:Push', 'Pawn:e6:Push', 'N2:2:1', 'K:0:-1', 'N2:-2:1', 'R1:2:0', 'K:1:1', 'Pawn:h7:TwoPush', 'N2:-2:1', 'K:1:-1', 'Q:d3', 'Q:e6', 'Pawn:g3:Push', 'Q:f7', 'Q:g3', 'Pawn:a7:TwoPush', 'R1:1:0', 'N1:2:-1', 'Q:f3', 'R2:1:0', 'R2:2:0', 'Pawn:a5:Push', 'R2:-4:0', 'Pawn:a4:CaptureRight', 'R2:0:1', 'N1:-2:1', 'Q:d1', 'N2:1:-2', 'Pawn:h3:Push', 'R2:1:0', 'Q:f3', 'Pawn:h5:CaptureLeft', 'Q:e2', 'N2:-1:2', 'K:-1:0', 'Pawn:g4:Push', 'K:0:1', 'N2:1:-2', 'K:0:-1', 'N2:-1:2', 'Q:f3', 'R2:-1:0', 'Q:e3', 'K:-1:1', 'Q:f3', 'R2:-1:0', 'Q:g3', 'Q:f6', 'R1:3:0', 'R2:1:0', 'R1:0:2', 'Q:h4', 'Q:h3', 'Q:h7', 'K:0:1', 'Q:h6', 'R2:1:0', 'Q:f4']
# 1. e4 g6 2. d4 Na6 3. c3 e6 4. Bg5 Be7 5. Bf6 Bxf6 6. Bc4 c6 7. Ne2 d5 8. exd5 cxd5 9. Bb3 Bd7 10. O-O Ne7 11. Ng3 Bg5 12. h3 Bc6 13. a3 b5 14. Nd2 O-O 15. Qf3 Nb4 16. Qg4 Bh6 17. Nde4 f5 18. Qd1 fxe4 19. Nf5 Qe8 20. Ng3 Rc8 21. Nf5 Qd7 22. g3 e5 23. Nxh6+ Kg7 24. Nf7 Rce8 25. Kh2 h5 26. Nd8 Kh6 27. Qd3 Qe6 28. g4 Qf7 29. Qg3 a5 30. Rab1 Nd3 31. Qf3 Rg8 32. Rh1 a4 33. Rhd1 axb3 34. Rd2 Nb4 35. Qd1 Nf5 36. h4 Rh8 37. Qf3 hxg4 38. Qe2 Ne7 39. Kg2 g3 40. Kxg3 Nf5+ 41. Kg2 Ne7 42. Qf3 Rhg8 43. Qe3+ Kg7 44. Qf3 Rgf8 45. Qg3 Qf6 46. Re1 Rg8 47. Re3 Qxh4 48. Qh3 Qh7 49. Kg3 Qh6 50. Rde2 Qf4+

# %%
def EncodeMoveSequence(move_list):
    game = chess_game_tracker.Game()
    for dec_move in move_list:
        game.make_dec_move(dec_move)
    return game, encode(['START'] + game.enc_moves)

def GetWeightedMovesFromModel(mdl, move_list):
    game, enc_moves = EncodeMoveSequence(move_list)
    #print (enc_moves, decode(enc_moves))

    t = torch.tensor(enc_moves, dtype=torch.long)
    t = t[-block_size:]
    t = t[None, :]
    #print (t, t.shape)

    logits, _ = mdl(t)
    logits = logits[:, -1, :]
    logits = logits[0]

    # print (logits.shape)

    legal = game.encoded_legal_moves()
    moves_and_weights = list(enumerate(logits.tolist()))
    moves_and_weights = sorted(moves_and_weights, key=lambda x: -x[1])
    
    final_list = []

    for i, val in moves_and_weights:
        if int_to_token[i] in legal:
            final_list.append((i, game.decode_possible_move(int_to_token[i]), val))
        else:
            final_list.append((i, None, val))
    return final_list

# %%
final_list = GetWeightedMovesFromModel(model, 
    [
        chess.Move.from_uci('e2e4'),
        chess.Move.from_uci('e7e5'),
    ])
print (final_list)
# Out:
# torch.Size([360])
# [(85, Move.from_uci('g1f3'), 13.457658767700195), (43, Move.from_uci('f1c4'), 12.329618453979492), (189, Move.from_uci('f2f4'), 12.046721458435059), (149, Move.from_uci('d2d4'), 11.555805206298828), (148, Move.from_uci('d2d3'), 11.010278701782227), (300, Move.from_uci('d1h5'), 10.938652038574219), (81, Move.from_uci('b1c3'), 10.879652976989746), (282, Move.from_uci('d1f3'), 9.8351469039917), (129, Move.from_uci('c2c4'), 8.967118263244629), (128, Move.from_uci('c2c3'), 8.822736740112305), (40, Move.from_uci('f1b5'), 8.541613578796387), (208, Move.from_uci('g2g3'), 8.396890640258789), (108, Move.from_uci('b2b3'), 8.351056098937988), (93, Move.from_uci('a2a3'), 8.247102737426758), (188, Move.from_uci('f2f3'), 8.039416313171387), (50, Move.from_uci('f1e2'), 7.533273696899414), (227, Move.from_uci('h2h3'), 7.4155049324035645), (273, Move.from_uci('d1e2'), 7.1841535568237305), (47, Move.from_uci('f1d3'), 7.040911674499512), (87, Move.from_uci('g1e2'), 6.89314079284668), (109, Move.from_uci('b2b4'), 6.892159461975098), (155, None, 6.538547039031982), (291, Move.from_uci('d1g4'), 6.527606964111328), (89, Move.from_uci('g1h3'), 6.261855602264404), (173, None, 6.00713586807251), (94, Move.from_uci('a2a4'), 5.874614715576172), (6, None, 5.821573257446289), (209, Move.from_uci('g2g4'), 5.757317066192627), (58, None, 5.380672931671143), (154, None, 5.358552932739258), (175, None, 4.995028018951416), (228, Move.from_uci('h2h4'), 4.781527519226074), (75, None, 4.516351699829102), (193, None, 4.437543869018555), (257, None, 4.415846824645996), (91, None, 4.315802574157715), (28, None, 4.2657999992370605), (169, None, 4.223247528076172), (195, None, 4.14533805847168), (19, None, 4.04087495803833), (192, None, 3.786916971206665), (83, None, 3.621699810028076), (252, None, 3.594092845916748), (265, None, 3.465311050415039), (152, None, 3.277252674102783), (268, None, 3.1281681060791016), (168, None, 3.1185190677642822), (174, None, 3.0736334323883057), (266, None, 2.905423641204834), (14, None, 2.8987271785736084), (157, None, 2.881237268447876), (90, None, 2.8783926963806152), (299, None, 2.8647408485412598), (77, Move.from_uci('b1a3'), 2.678874969482422), (24, None, 2.5842437744140625), (86, None, 2.5318288803100586), (232, None, 2.5115678310394287), (250, None, 2.485131025314331), (88, None, 2.3913216590881348), (132, None, 2.3900656700134277), (243, None, 2.181459665298462), (57, None, 2.10105299949646), (3, None, 2.033308267593384), (79, None, 2.0219314098358154), (290, None, 2.0137717723846436), (11, None, 1.9274942874908447), (115, None, 1.8868038654327393), (267, None, 1.8640775680541992), (20, None, 1.8118798732757568), (256, None, 1.8015835285186768), (15, None, 1.7455902099609375), (332, None, 1.7319968938827515), (230, None, 1.6789156198501587), (135, None, 1.6439322233200073), (264, None, 1.6040458679199219), (63, None, 1.5847303867340088), (112, None, 1.5760457515716553), (82, None, 1.5095082521438599), (96, None, 1.475386381149292), (172, None, 1.4524519443511963), (275, None, 1.3767997026443481), (134, None, 1.3564422130584717), (23, None, 1.320786476135254), (27, None, 1.2936149835586548), (42, None, 1.1756665706634521), (284, None, 1.132941484451294), (146, None, 1.0576672554016113), (292, None, 1.0386089086532593), (71, Move.from_uci('e1e2'), 1.0176405906677246), (54, None, 0.9188684225082397), (285, None, 0.8912963271141052), (48, None, 0.8786090016365051), (334, None, 0.8468101024627686), (212, None, 0.8366080522537231), (84, None, 0.8273699283599854), (156, None, 0.8229590058326721), (80, None, 0.8175703287124634), (131, None, 0.7871947288513184), (215, None, 0.6420228481292725), (139, None, 0.5303298234939575), (321, None, 0.509191632270813), (322, None, 0.5010271072387695), (153, None, 0.482901930809021), (158, None, 0.43826282024383545), (320, None, 0.4317089915275574), (325, None, 0.32806289196014404), (276, None, 0.30126214027404785), (111, None, 0.2834455966949463), (98, None, 0.23863011598587036), (247, None, 0.22450 ...

# %%
game, enc_moves = EncodeMoveSequence(
    [
        chess.Move.from_uci('e2e4'),
        chess.Move.from_uci('e7e5'),
    ])
print (enc_moves, decode(enc_moves))

t = torch.tensor(enc_moves, dtype=torch.long)
t = t[-block_size:]
t = t[None, :]
print (t, t.shape)

logits, _ = model(t)
logits = logits[:, -1, :]
logits = logits[0]

print (logits.shape)

legal = game.encoded_legal_moves()
moves_and_weights = list(enumerate(logits.tolist()))
moves_and_weights = sorted(moves_and_weights, key=lambda x: -x[1])

for i, val in moves_and_weights:
    if int_to_token[i] in legal:
        print (game.decode_possible_move(int_to_token[i]), val)
    else:
        print ("ILLEGAL", int_to_token[i], val)
# Out:
# [1, 169, 185] ['START', 'Pawn:e2:TwoPush', 'Pawn:e7:TwoPush']
# tensor([[  1, 169, 185]]) torch.Size([1, 3])
# torch.Size([360])
# g1f3 13.457658767700195
# f1c4 12.329618453979492
# f2f4 12.046721458435059
# d2d4 11.555805206298828
# d2d3 11.010278701782227
# d1h5 10.938652038574219
# b1c3 10.879652976989746
# d1f3 9.8351469039917
# c2c4 8.967118263244629
# c2c3 8.822736740112305
# f1b5 8.541613578796387
# g2g3 8.396890640258789
# b2b3 8.351056098937988
# a2a3 8.247102737426758
# f2f3 8.039416313171387
# f1e2 7.533273696899414
# h2h3 7.4155049324035645
# d1e2 7.1841535568237305
# f1d3 7.040911674499512
# g1e2 6.89314079284668
# b2b4 6.892159461975098
# ILLEGAL Pawn:d4:Push 6.538547039031982
# d1g4 6.527606964111328
# g1h3 6.261855602264404
# ILLEGAL Pawn:e4:CaptureLeft 6.00713586807251
# a2a4 5.874614715576172
# ILLEGAL BD:b2 5.821573257446289
# g2g4 5.757317066192627
# ILLEGAL BL:g2 5.380672931671143
# ILLEGAL Pawn:d4:CaptureRight 5.358552932739258
# ILLEGAL Pawn:e4:Push 4.995028018951416
# h2h4 4.781527519226074
# ILLEGAL K:2:0 4.516351699829102
# ILLEGAL Pawn:f4:CaptureLeft 4.437543869018555
# ILLEGAL Q:c2 4.415846824645996
# ILLEGAL N2:2:1 4.315802574157715
# ILLEGAL BD:g5 4.2657999992370605
# ILLEGAL Pawn:e2:TwoPush 4.223247528076172
# ILLEGAL Pawn:f4:Push 4.14533805847168
# ILLEGAL BD:e3 4.04087495803833
# ILLEGAL Pawn:f3:Push 3.786916971206665
# ILLEGAL N1:2:1 3.621699810028076
# ILLEGAL Q:b5 3.594092845916748
# ILLEGAL Q:d2 3.465311050415039
# ILLEGAL Pawn:d3:Push 3.277252674102783
# ILLEGAL Q:d5 3.1281681060791016
# ILLEGAL Pawn:e2:Push 3.1185190677642822
# ILLEGAL Pawn:e4:CaptureRight 3.0736334323883057
# ILLEGAL Q:d3 2.905423641204834
# ILLEGAL BD:d2 2.8987271785736084
# ILLEGAL Pawn:d5:CaptureRight 2.881237268447876
# ILLEGAL N2:2:-1 2.8783926963806152
# ILLEGAL Q:h4 2.8647408485412598
# b1a3 2.678874969482422
# ILLEGAL BD:f6 2.5842437744140625
# ILLEGAL N2:-2:-1 2.5318288803100586
# ILLEGAL Pawn:h4:Push 2.5115678310394287
# ILLEGAL Q:b3 2.485131025314331
# ILLEGAL N2:1:-2 2.3913216590881348
# ILLEGAL Pawn:c3:Push 2.3900656700134277
# ILLEGAL Q:a4 2.181459665298462
# ILLEGAL BL:f7 2.10105299949646
# ILLEGAL BD:a3 2.033308267593384
# ILLEGAL N1:-2:1 2.0219314098358154
# ILLEGAL Q:g3 2.0137717723846436
# ILLEGAL BD:c3 1.9274942874908447
# ILLEGAL Pawn:b4:Push 1.8868038654327393
# ILLEGAL Q:d4 1.8640775680541992
# ILLEGAL BD:e5 1.8118798732757568
# ILLEGAL Q:c1 1.8015835285186768
# ILLEGAL BD:d4 1.7455902099609375
# ILLEGAL R2:-1:0 1.7319968938827515
# ILLEGAL Pawn:h3:Push 1.6789156198501587
# ILLEGAL Pawn:c4:Push 1.6439322233200073
# ILLEGAL Q:d1 1.6040458679199219
# ILLEGAL BL:h3 1.5847303867340088
# ILLEGAL Pawn:b3:Push 1.5760457515716553
# ILLEGAL N1:2:-1 1.5095082521438599
# ILLEGAL Pawn:a3:Push 1.475386381149292
# ILLEGAL Pawn:e3:Push 1.4524519443511963
# ILLEGAL Q:e4 1.3767997026443481
# ILLEGAL Pawn:c4:CaptureRight 1.3564422130584717
# ILLEGAL BD:f4 1.320786476135254
# ILLEGAL BD:g3 1.2936149835586548
# ILLEGAL BL:c2 1.1756665706634521
# ILLEGAL Q:f5 1.132941484451294
# ILLEGAL Pawn:d2:CaptureLeft 1.0576672554016113
# ILLEGAL Q:g5 1.0386089086532593
# e1e2 1.0176405906677246
# ILLEGAL BL:f1 0.9188684225082397
# ILLEGAL Q:f6 0.8912963271141052
# ILLEGAL BL:d5 0.8786090016365051
# ILLEGAL R2:-3:0 0.8468101024627686
# ILLEGAL Pawn:g3:Push 0.8366080522537231
# ILLEGAL N2:-1:-2 0.8273699283599854
# ILLEGAL Pawn:d5:CaptureLeft 0.8229590058326721
# ILLEGAL N1:1:-2 0.8175703287124634
# ILLEGAL Pawn:c3:CaptureRight 0.7871947288513184
# ILLEGAL Pawn:g4:Push 0.6420228481292725
# ILLEGAL Pawn:c6:CaptureLeft 0.5303298234939575
# ILLEGAL R1:0:4 0.509191632270813
# ILLEGAL R1:0:5 0.5010271072387695
# ILLEGAL Pawn:d4:CaptureLeft 0.482901930809021
# ILLEGAL Pawn:d5:Push 0.43826282024383545
# ILLEGAL R1:0:3 0.4317089915275574
# ILLEGAL R1:1:0 0.32806289196014404
# ILLEGAL Q:e5 0.30126214027404785
# ILLEGAL Pawn:b3:CaptureRight 0.2834455966949463
# ILLEGAL Pawn:a4:Push 0.23863011598587036
# ILLEGAL Q:a8 0.22450268268585205
# ILLEGAL R1:2:0 0.19893121719360352
# f1a6 0.19385218620300293
# ILLEGAL R1:0:7 0.08800092339515686
# ILLEGAL BL:c6 0.07185438275337219
# ILLEGAL BL:a4 0.007261157035827637
# ILLEGAL K:1:0 0.004140496253967285
# ILLEGAL BL:h5 -0.0014045238494873047
# ILLEGAL Pawn:f5:CaptureLeft -0.053846657276153564
# ILLEGAL Q:e3 -0.1581183671951294
# ILLEGAL BL:g4 -0.1906965970993042
# ILLEGAL Pawn:c4:CaptureLeft -0.27891290187835693
# ILLEGAL BL:f3 -0.3015817403793335
# ILLEGAL BD:h4 -0.344862699508667
# ILLEGAL Pawn:d7:TwoPush -0.35867029428482056
# ILLEGAL Q:f4 -0.37691590189933777
# ILLEGAL Q:b4 -0.4019836187362671
# ILLEGAL Q:d6 -0.49220341444015503
# ILLEGAL R1:0:6 -0.5055804252624512
# ILLEGAL BD:g7 -0.623582124710083
# ILLEGAL R1:0:1 -0.6566085815429688
# ILLEGAL Pawn:h5:Push -0.6607131958007812
# ILLEGAL Pawn:b2:CaptureRight -0.6655534505844116
# ILLEGAL Q:e1 -0.6903395652770996
# ILLEGAL BD:h2 -0.7333303689956665
# ILLEGAL BL:b3 -0.7511618137359619
# ILLEGAL K:-2:0 -0.7862890362739563
# ILLEGAL N1:-1:-2 -0.8488427400588989
# ILLEGAL BL:g8 -0.9270843267440796
# ILLEGAL Q:g2 -0.9934917688369751
# ILLEGAL R2:-4:0 -0.9956359267234802
# ILLEGAL R1:-1:0 -1.024178385734558
# ILLEGAL R2:0:4 -1.1898608207702637
# ILLEGAL R1:-2:0 -1.2098064422607422
# ILLEGAL BL:a8 -1.2305313348770142
# ILLEGAL BD:c1 -1.2423920631408691
# ILLEGAL BD:h8 -1.2657277584075928
# ILLEGAL BD:a1 -1.2968770265579224
# ILLEGAL Q:c3 -1.299682855606079
# ILLEGAL Q:c7 -1.3133180141448975
# ILLEGAL BL:e4 -1.3959705829620361
# ILLEGAL K:-1:1 -1.4384664297103882
# ILLEGAL Q:c8 -1.455028772354126
# ILLEGAL BD:f8 -1.5150216817855835
# ILLEGAL Pawn:a5:Push -1.5627164840698242
# ILLEGAL Q:h3 -1.565889596939087
# ILLEGAL BD:d6 -1.5903476476669312
# ILLEGAL Pawn:a5:CaptureRight -1.6191692352294922
# ILLEGAL Q:c4 -1.636093258857727
# ILLEGAL BD:b4 -1.6605875492095947
# ILLEGAL Pawn:d3:CaptureLeft -1.665531873703003
# ILLEGAL Pawn:e5:CaptureRight -1.7883199453353882
# ILLEGAL BD:e7 -1.8000434637069702
# ILLEGAL R2:2:0 -1.8551138639450073
# ILLEGAL Pawn:d3:CaptureRight -1.8866709470748901
# ILLEGAL K:1:1 -1.8921966552734375
# ILLEGAL Q:c5 -1.905311942100525
# ILLEGAL Pawn:e5:CaptureLeft -1.9198166131973267
# ILLEGAL Q:b7 -1.922581672668457
# ILLEGAL Pawn:f2:CaptureRight -1.9383761882781982
# ILLEGAL Pawn:b7:Push -1.9800513982772827
# ILLEGAL R2:0:5 -1.9877040386199951
# ILLEGAL Q:e7 -2.0025596618652344
# ILLEGAL BL:g6 -2.011482000350952
# ILLEGAL Pawn:b4:CaptureRight -2.023886203765869
# ILLEGAL R2:-2:0 -2.031080722808838
# ILLEGAL Pawn:c5:CaptureLeft -2.037020683288574
# ILLEGAL Pawn:c5:Push -2.0545382499694824
# ILLEGAL R1:0:2 -2.056859016418457
# ILLEGAL Pawn:g3:CaptureLeft -2.056990146636963
# ILLEGAL R1:7:0 -2.0754783153533936
# ILLEGAL Pawn:c2:CaptureLeft -2.1512668132781982
# ILLEGAL R2:4:0 -2.2605552673339844
# ILLEGAL BD:c5 -2.2842400074005127
# ILLEGAL BL:d7 -2.3028149604797363
# ILLEGAL Pawn:a2:CaptureRight -2.3092095851898193
# ILLEGAL Pawn:e6:CaptureLeft -2.3149633407592773
# ILLEGAL BL:b7 -2.329760789871216
# ILLEGAL Pawn:e7:Push -2.3312361240386963
# ILLEGAL Q:d8 -2.3562238216400146
# ILLEGAL Pawn:e5:Push -2.3576035499572754
# ILLEGAL Pawn:f3:CaptureLeft -2.365542411804199
# ILLEGAL BL:c8 -2.379179000854492
# ILLEGAL Q:h2 -2.3902714252471924
# ILLEGAL BD:b8 -2.4216673374176025
# ILLEGAL Q:c6 -2.4596242904663086
# ILLEGAL BD:b6 -2.492374897003174
# ILLEGAL Pawn:b2:CaptureLeft -2.52437686920166
# ILLEGAL Q:a5 -2.5583553314208984
# ILLEGAL Pawn:c3:CaptureLeft -2.572545051574707
# ILLEGAL Pawn:e3:CaptureLeft -2.5745081901550293
# ILLEGAL Pawn:d2:CaptureRight -2.579007863998413
# ILLEGAL Q:b1 -2.58597731590271
# ILLEGAL Pawn:d7:Push -2.6048336029052734
# ILLEGAL Pawn:b5:CaptureRight -2.6653778553009033
# ILLEGAL R1:-7:0 -2.7185215950012207
# ILLEGAL R2:-5:0 -2.7438788414001465
# ILLEGAL Pawn:h6:Push -2.7681336402893066
# ILLEGAL Pawn:h4:CaptureLeft -2.777245044708252
# ILLEGAL Pawn:a4:CaptureRight -2.7809629440307617
# ILLEGAL Pawn:f2:CaptureLeft -2.786797046661377
# ILLEGAL Pawn:f7:TwoPush -2.791551113128662
# ILLEGAL R2:0:3 -2.831026077270508
# ILLEGAL Pawn:g4:CaptureRight -2.845557689666748
# ILLEGAL Pawn:c6:CaptureRight -2.8616743087768555
# ILLEGAL BD:c7 -2.867220878601074
# ILLEGAL Pawn:f4:CaptureRight -2.900437355041504
# ILLEGAL Pawn:b4:CaptureLeft -2.9370100498199463
# ILLEGAL Pawn:a3:CaptureRight -2.950039863586426
# ILLEGAL BL:h1 -2.9531781673431396
# ILLEGAL BL:a2 -2.953298568725586
# ILLEGAL Pawn:g5:CaptureLeft -2.969754219055176
# ILLEGAL BD:h6 -2.9740915298461914
# ILLEGAL Q:e6 -2.9821455478668213
# ILLEGAL Pawn:c7:Push -3.0066370964050293
# ILLEGAL Pawn:f7:Push -3.010923385620117
# ILLEGAL R1:3:0 -3.024974822998047
# ILLEGAL R1:5:0 -3.1152706146240234
# ILLEGAL N1:-2:-1 -3.12972092628479
# ILLEGAL Q:d7 -3.151580810546875
# ILLEGAL Pawn:g2:CaptureLeft -3.17604398727417
# ILLEGAL R1:4:0 -3.211024045944214
# ILLEGAL Pawn:c7:CaptureRight -3.2505712509155273
# ILLEGAL BD:e1 -3.306370973587036
# ILLEGAL Pawn:c2:CaptureRight -3.307068109512329
# ILLEGAL Pawn:c7:TwoPush -3.3195784091949463
# ILLEGAL Q:f2 -3.3215725421905518
# ILLEGAL Pawn:f6:Push -3.328364849090576
# ILLEGAL Pawn:a6:CaptureRight -3.361912727355957
# ILLEGAL Pawn:h3:CaptureLeft -3.388273239135742
# ILLEGAL Q:g8 -3.3926475048065186
# ILLEGAL Q:a7 -3.424898386001587
# ILLEGAL Q:a1 -3.432805299758911
# ILLEGAL Pawn:b5:CaptureLeft -3.5030455589294434
# ILLEGAL BL:f5 -3.5101873874664307
# ILLEGAL K:-1:-1 -3.5123939514160156
# ILLEGAL BD:a7 -3.5201640129089355
# ILLEGAL BD:g1 -3.549437999725342
# ILLEGAL R2:0:1 -3.5768330097198486
# ILLEGAL Q:g1 -3.586754322052002
# ILLEGAL BD:f2 -3.610795259475708
# ILLEGAL Q:a3 -3.6262502670288086
# ILLEGAL K:0:-1 -3.6547558307647705
# ILLEGAL R1:0:-7 -3.666013479232788
# ILLEGAL K:-1:0 -3.686404228210449
# ILLEGAL Pawn:e6:CaptureRight -3.7169902324676514
# ILLEGAL R2:1:0 -3.727909564971924
# ILLEGAL Q:b6 -3.782719612121582
# ILLEGAL R1:-3:0 -3.786813974380493
# ILLEGAL Pawn:f5:CaptureRight -3.8387675285339355
# ILLEGAL Pawn:b7:CaptureLeft -3.851569890975952
# ILLEGAL R2:6:0 -3.860462188720703
# ILLEGAL Q:e8 -3.8775341510772705
# ILLEGAL Q:h1 -3.8916125297546387
# ILLEGAL Pawn:b6:CaptureRight -3.900658130645752
# ILLEGAL Pawn:e7:TwoPush -3.9696145057678223
# ILLEGAL Pawn:e2:CaptureRight -3.9703409671783447
# ILLEGAL Pawn:g7:Push -3.9938488006591797
# ILLEGAL BL:d1 -4.01275110244751
# ILLEGAL BL:h7 -4.094796657562256
# ILLEGAL Pawn:e3:CaptureRight -4.139679431915283
# ILLEGAL Q:h7 -4.145976543426514
# ILLEGAL Pawn:a7:Push -4.170660972595215
# ILLEGAL Pawn:b6:CaptureLeft -4.26871395111084
# ILLEGAL Pawn:g6:Push -4.3160858154296875
# ILLEGAL R1:-6:0 -4.31773567199707
# ILLEGAL Pawn:g6:CaptureLeft -4.340754508972168
# ILLEGAL Q:a6 -4.402536392211914
# ILLEGAL BL:b1 -4.410806655883789
# ILLEGAL R2:0:7 -4.424980640411377
# ILLEGAL Q:f7 -4.45170783996582
# ILLEGAL R2:0:2 -4.452173709869385
# ILLEGAL Pawn:h5:CaptureLeft -4.554150104522705
# ILLEGAL Pawn:g5:Push -4.5674662590026855
# ILLEGAL Q:g7 -4.571224689483643
# ILLEGAL Q:f1 -4.6109619140625
# ILLEGAL R1:0:-1 -4.638189315795898
# ILLEGAL Pawn:g7:TwoPush -4.650211334228516
# ILLEGAL R1:0:-2 -4.673208236694336
# ILLEGAL R2:7:0 -4.694976329803467
# ILLEGAL Pawn:c5:CaptureRight -4.7796406745910645
# ILLEGAL Q:f8 -4.782405853271484
# ILLEGAL R1:6:0 -4.78282356262207
# ILLEGAL Pawn:g3:CaptureRight -4.783346652984619
# ILLEGAL BL:e8 -4.788930416107178
# ILLEGAL Q:b2 -4.789668083190918
# ILLEGAL Pawn:d6:CaptureLeft -4.855337619781494
# ILLEGAL Pawn:f6:CaptureLeft -4.869451522827148
# ILLEGAL R1:0:-4 -4.927880764007568
# ILLEGAL Q:a2 -4.936310768127441
# ILLEGAL R2:3:0 -4.9614105224609375
# ILLEGAL Pawn:g5:CaptureRight -4.976792335510254
# ILLEGAL Pawn:f7:CaptureLeft -5.057049751281738
# ILLEGAL Pawn:b7:CaptureRight -5.167957782745361
# ILLEGAL BD:d8 -5.267509937286377
# ILLEGAL Pawn:e7:CaptureLeft -5.284786224365234
# ILLEGAL R2:-7:0 -5.325052738189697
# ILLEGAL Q:g6 -5.328939437866211
# ILLEGAL Q:b8 -5.352643013000488
# ILLEGAL R2:5:0 -5.355815887451172
# ILLEGAL Pawn:c6:Push -5.385382652282715
# ILLEGAL R2:0:-1 -5.390727996826172
# ILLEGAL Pawn:b6:Push -5.590307712554932
# ILLEGAL Pawn:h7:Push -5.733476638793945
# ILLEGAL R1:-5:0 -5.748074531555176
# ILLEGAL Pawn:g6:CaptureRight -5.769654273986816
# ILLEGAL Pawn:b7:TwoPush -5.795561790466309
# ILLEGAL Pawn:g7:CaptureRight -5.830902099609375
# ILLEGAL Pawn:g2:CaptureRight -5.83763313293457
# ILLEGAL K:1:-1 -5.840171813964844
# ILLEGAL Pawn:d6:CaptureRight -5.869768142700195
# ILLEGAL R2:-6:0 -5.871219635009766
# ILLEGAL Pawn:a6:Push -5.915350914001465
# ILLEGAL BL:e6 -5.927085876464844
# ILLEGAL R2:0:-3 -5.942129135131836
# ILLEGAL Pawn:c7:CaptureLeft -6.059454441070557
# ILLEGAL BD:a5 -6.11673641204834
# ILLEGAL Pawn:e6:Push -6.118013858795166
# ILLEGAL Pawn:g4:CaptureLeft -6.127012252807617
# ILLEGAL Q:h8 -6.134182929992676
# ILLEGAL Pawn:h2:CaptureLeft -6.176316261291504
# ILLEGAL Q:h6 -6.242611885070801
# ILLEGAL Pawn:b5:Push -6.275869369506836
# ILLEGAL Pawn:e2:CaptureLeft -6.540619850158691
# ILLEGAL Pawn:f3:CaptureRight -6.544231414794922
# ILLEGAL Pawn:d6:Push -6.545062065124512
# ILLEGAL Pawn:b3:CaptureLeft -6.575407981872559
# ILLEGAL R1:-4:0 -6.617455005645752
# ILLEGAL R2:0:-5 -6.638232231140137
# ILLEGAL R1:0:-3 -6.66163444519043
# ILLEGAL Pawn:f5:Push -6.667922019958496
# ILLEGAL Pawn:e7:CaptureRight -6.699304103851318
# ILLEGAL Pawn:g7:CaptureLeft -6.822736740112305
# ILLEGAL R2:0:6 -6.983778953552246
# ILLEGAL R1:0:-5 -7.027210712432861
# ILLEGAL Pawn:d7:CaptureRight -7.133396625518799
# ILLEGAL Pawn:h7:CaptureLeft -7.311090469360352
# ILLEGAL Pawn:f7:CaptureRight -7.521665573120117
# ILLEGAL R2:0:-2 -7.540928840637207
# ILLEGAL Pawn:h7:TwoPush -7.543766021728516
# ILLEGAL R2:0:-4 -7.760809421539307
# ILLEGAL Pawn:h6:CaptureLeft -7.792586326599121
# ILLEGAL Pawn:a7:CaptureRight -7.86105489730835
# ILLEGAL R2:0:-7 -8.047456741333008
# ILLEGAL R1:0:-6 -8.253604888916016
# ILLEGAL Pawn:a7:TwoPush -8.427021980285645
# ILLEGAL R2:0:-6 -8.679098129272461
# ILLEGAL Pawn:f6:CaptureRight -9.180593490600586
# ILLEGAL Pawn:d7:CaptureLeft -9.800003051757812
# ILLEGAL ZERO -15.781384468078613
# ILLEGAL START -15.92744255065918
