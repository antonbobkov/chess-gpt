# %%
import chess
import chess.pgn
import chess_encode
import chess_decode


import time

filepath = "..\\data_pgn\\lichess_db_standard_rated_2014-07.pgn"
intermediate_filepath = "..\\data_v2\\intermediate_non_bullet.txt"
tokens_filepath = "..\\data_v2\\tokens.txt"

# %%
pgn = open(filepath)

first_game = chess.pgn.read_game(pgn)
second_game = chess.pgn.read_game(pgn)

print(first_game.headers["Event"])
print(int(first_game.headers["BlackElo"]))
print(int(first_game.headers["WhiteElo"]))
# Out:
# Rated Blitz game
# 1518
# 1567

# %%
def encode_game_with_check(game):
    encoder = chess_encode.EncoderBoard()
    decoder = chess_decode.DecoderBoard()
    moves = []

    for move in game.mainline_moves():
        enc_move = encoder.EncodeMove(move)
        if enc_move == None:
            break
        moves.append(enc_move)
        dec_move = decoder.DecodeMove(enc_move)
        assert move == dec_move
    return moves

# %%
pgn = open(filepath)

first_game = chess.pgn.read_game(pgn)

encode_game_with_check(first_game)

# %%
def try_parse_int(s, val):
  try:
    return int(s)
  except ValueError:
    return val

def clean_elo_str(elo):
    return try_parse_int(elo.replace('?', ''), 0)

# %%
from collections import defaultdict

event = defaultdict(int)
elos = defaultdict(int)

seconds = time.time()
total = time.time()

token_set = set()

with open(filepath) as pgn:
    with open(intermediate_filepath, "w") as out_file:
        for i in range(100000):
            if i % 5000 == 0:        
                print (i, round(time.time() - seconds, 2), "sec")
                print ("total", round(time.time() - total, 2), "sec")
                seconds = time.time()
                print (event)
                print (elos)
                print ("")

            game = chess.pgn.read_game(pgn)
            ev = " ".join(game.headers["Event"].split()[:2])
            if 'Bullet' in ev:
                continue 
            el1 = clean_elo_str(game.headers["BlackElo"]) // 100
            el2 = clean_elo_str(game.headers["WhiteElo"]) // 100

#             if el1 < 18 or el2 < 18:
#                 continue

            move_seq = encode_game_with_check(game)
            token_set.update(move_seq)
            out_file.write(" ".join(move_seq) + "\n")

            event[ev] += 1
            elos[el1] += 1
            elos[el2] += 1

token_list = sorted(list(token_set))

with open(tokens_filepath, "w") as out_file:
    out_file.write("\n".join(token_list) + "\n")
# Out:
# 0 0.0 sec
# total 0.0 sec
# defaultdict(<class 'int'>, {})
# defaultdict(<class 'int'>, {})
#
# 5000 12.08 sec
# total 12.08 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 1805, 'Rated Classical': 1055, 'Rated Correspondence': 18})
# defaultdict(<class 'int'>, {15: 1064, 13: 565, 14: 790, 18: 479, 19: 230, 12: 431, 16: 948, 11: 172, 17: 859, 21: 28, 20: 96, 8: 4, 9: 18, 7: 4, 10: 58, 23: 2, 24: 4, 25: 4})
#
# 10000 11.99 sec
# total 24.07 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 3856, 'Rated Classical': 2386, 'Rated Correspondence': 31})
# defaultdict(<class 'int'>, {15: 2362, 13: 1167, 14: 1770, 18: 1026, 19: 428, 12: 796, 16: 2176, 11: 358, 17: 2002, 21: 47, 20: 198, 8: 19, 9: 27, 7: 11, 10: 138, 23: 2, 24: 4, 25: 4, 22: 11})
#
# 15000 11.79 sec
# total 35.85 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 5750, 'Rated Classical': 3678, 'Rated Correspondence': 46})
# defaultdict(<class 'int'>, {15: 3439, 13: 1794, 14: 2691, 18: 1584, 19: 692, 12: 1165, 16: 3354, 11: 476, 17: 3045, 21: 103, 20: 331, 8: 19, 9: 35, 7: 11, 10: 181, 23: 3, 24: 4, 25: 4, 22: 17})
#
# 20000 12.16 sec
# total 48.02 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 7709, 'Rated Classical': 5003, 'Rated Correspondence': 54})
# defaultdict(<class 'int'>, {15: 4576, 13: 2426, 14: 3633, 18: 2242, 19: 991, 12: 1519, 16: 4530, 11: 586, 17: 3969, 21: 197, 20: 494, 8: 20, 9: 56, 7: 17, 10: 245, 23: 6, 24: 4, 25: 4, 22: 17})
#
# 25000 12.16 sec
# total 60.17 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 9591, 'Rated Classical': 6337, 'Rated Correspondence': 62})
# defaultdict(<class 'int'>, {15: 5737, 13: 3043, 14: 4558, 18: 2832, 19: 1262, 12: 1923, 16: 5604, 11: 752, 17: 4855, 21: 242, 20: 670, 8: 57, 9: 75, 7: 20, 10: 316, 23: 6, 24: 4, 25: 4, 22: 20})
#
# 30000 12.24 sec
# total 72.41 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 11413, 'Rated Classical': 7836, 'Rated Correspondence': 75})
# defaultdict(<class 'int'>, {15: 6918, 13: 3741, 14: 5479, 18: 3422, 19: 1523, 12: 2331, 16: 6760, 11: 902, 17: 5809, 21: 280, 20: 865, 8: 57, 9: 91, 7: 22, 10: 410, 23: 7, 24: 4, 25: 4, 22: 23})
#
# 35000 11.99 sec
# total 84.41 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 13335, 'Rated Classical': 9133, 'Rated Correspondence': 89})
# defaultdict(<class 'int'>, {15: 8122, 13: 4464, 14: 6412, 18: 3923, 19: 1758, 12: 2773, 16: 7740, 11: 1080, 17: 6794, 21: 318, 20: 997, 8: 58, 9: 108, 7: 29, 10: 492, 23: 7, 24: 6, 25: 4, 22: 29})
#
# 40000 11.79 sec
# total 96.2 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 15237, 'Rated Classical': 10437, 'Rated Correspondence': 100})
# defaultdict(<class 'int'>, {15: 9308, 13: 5145, 14: 7208, 18: 4470, 19: 2035, 12: 3205, 16: 8806, 11: 1238, 17: 7759, 21: 360, 20: 1182, 8: 58, 9: 125, 7: 29, 10: 562, 23: 12, 24: 6, 25: 4, 22: 35, 0: 1})
#
# 45000 11.89 sec
# total 108.09 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 17192, 'Rated Classical': 11834, 'Rated Correspondence': 111})
# defaultdict(<class 'int'>, {15: 10560, 13: 5738, 14: 8137, 18: 5129, 19: 2290, 12: 3598, 16: 9841, 11: 1397, 17: 8876, 21: 396, 20: 1369, 8: 60, 9: 129, 7: 58, 10: 619, 23: 24, 24: 6, 25: 4, 22: 41, 0: 2})
#
# 50000 12.07 sec
# total 120.16 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 19220, 'Rated Classical': 13267, 'Rated Correspondence': 129})
# defaultdict(<class 'int'>, {15: 11807, 13: 6438, 14: 9083, 18: 5767, 19: 2607, 12: 3949, 16: 11085, 11: 1584, 17: 9873, 21: 459, 20: 1535, 8: 65, 9: 146, 7: 60, 10: 681, 23: 30, 24: 7, 25: 4, 22: 50, 0: 2})
#
# 55000 12.09 sec
# total 132.25 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 21207, 'Rated Classical': 14629, 'Rated Correspondence': 170})
# defaultdict(<class 'int'>, {15: 13194, 13: 7097, 14: 10025, 18: 6379, 19: 2898, 12: 4268, 16: 12298, 11: 1720, 17: 10877, 21: 488, 20: 1648, 8: 66, 9: 168, 7: 61, 10: 719, 23: 31, 24: 7, 25: 4, 22: 62, 0: 2})
#
# 60000 12.15 sec
# total 144.4 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 23010, 'Rated Classical': 15967, 'Rated Correspondence': 179})
# defaultdict(<class 'int'>, {15: 14338, 13: 7665, 14: 11002, 18: 6907, 19: 3197, 12: 4631, 16: 13386, 11: 1818, 17: 11866, 21: 517, 20: 1778, 8: 66, 9: 176, 7: 64, 10: 791, 23: 31, 24: 7, 25: 4, 22: 66, 0: 2})
#
# 65000 12.38 sec
# total 156.78 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 24834, 'Rated Classical': 17205, 'Rated Correspondence': 187})
# defaultdict(<class 'int'>, {15: 15384, 13: 8295, 14: 11868, 18: 7590, 19: 3514, 12: 4975, 16: 14354, 11: 1958, 17: 12777, 21: 556, 20: 1884, 8: 69, 9: 201, 7: 65, 10: 847, 23: 31, 24: 7, 25: 4, 22: 71, 0: 2})
#
# 70000 12.04 sec
# total 168.82 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 26738, 'Rated Classical': 18448, 'Rated Correspondence': 207})
# defaultdict(<class 'int'>, {15: 16496, 13: 8971, 14: 12815, 18: 8160, 19: 3779, 12: 5410, 16: 15372, 11: 2145, 17: 13666, 21: 572, 20: 2014, 8: 81, 9: 211, 7: 65, 10: 908, 23: 32, 24: 7, 25: 4, 22: 76, 0: 2})
#
# 75000 11.83 sec
# total 180.65 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 28796, 'Rated Classical': 19873, 'Rated Correspondence': 218})
# defaultdict(<class 'int'>, {15: 17648, 13: 9679, 14: 13752, 18: 8922, 19: 4152, 12: 5780, 16: 16526, 11: 2331, 17: 14641, 21: 601, 20: 2242, 8: 83, 9: 217, 7: 65, 10: 984, 23: 50, 24: 8, 25: 4, 22: 87, 0: 2})
#
# 80000 11.84 sec
# total 192.5 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 30781, 'Rated Classical': 21171, 'Rated Correspondence': 229})
# defaultdict(<class 'int'>, {15: 18904, 13: 10277, 14: 14755, 18: 9519, 19: 4444, 12: 6113, 16: 17666, 11: 2467, 17: 15573, 21: 663, 20: 2380, 8: 87, 9: 232, 7: 65, 10: 1054, 23: 51, 24: 8, 25: 4, 22: 98, 0: 2})
#
# 85000 12.21 sec
# total 204.71 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 32817, 'Rated Classical': 22504, 'Rated Correspondence': 256})
# defaultdict(<class 'int'>, {15: 20264, 13: 10984, 14: 15739, 18: 10158, 19: 4795, 12: 6468, 16: 18757, 11: 2615, 17: 16451, 21: 727, 20: 2521, 8: 91, 9: 266, 7: 65, 10: 1088, 23: 51, 24: 8, 25: 4, 22: 100, 0: 2})
#
# 90000 12.28 sec
# total 216.99 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 34776, 'Rated Classical': 23915, 'Rated Correspondence': 260})
# defaultdict(<class 'int'>, {15: 21494, 13: 11681, 14: 16824, 18: 10865, 19: 5095, 12: 6814, 16: 19904, 11: 2760, 17: 17310, 21: 759, 20: 2639, 8: 96, 9: 283, 7: 66, 10: 1132, 23: 56, 24: 8, 25: 4, 22: 110, 0: 2})
#
# 95000 12.35 sec
# total 229.34 sec
# defaultdict(<class 'int'>, {'Rated Blitz': 36588, 'Rated Classical': 25364, 'Rated Correspondence': 280})
# defaultdict(<class 'int'>, {15: 22705, 13: 12326, 14: 17875, 18: 11514, 19: 5421, 12: 7142, 16: 20955, 11: 2902, 17: 18228, 21: 803, 20: 2761, 8: 98, 9: 290, 7: 66, 10: 1187, 23: 57, 24: 8, 25: 4, 22: 120, 0: 2})
